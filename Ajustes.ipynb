# %%
import pandas as pd

data = pd.read_csv('Final_Dataset1_1.csv', sep=',', index_col=0)

#data["CH4 in Land use change and forestry (tonnes CO₂e)"] = data["CH4 in Land use change and forestry (tonnes CO₂e)"].mul(-1)

display(data)
# Out:
#       Average global mean temperature anomalies in degrees Celsius  \
# Year
# 1998                                             0.6344
# 1999                                             0.4438
# 2000                                             0.4262
# 2001                                             0.5473
# 2002                                             0.6023
# 2003                                             0.6134
# 2004                                             0.5783
# 2005                                             0.6585
# 2006                                             0.6125
# 2007                                             0.6100
# 2008                                             0.5419
# 2009                                             0.6367
# 2010                                             0.7014
# 2011                                             0.5788
# 2012                                             0.6240
# ...

# %%
data.to_csv('Final_Dataset1_2.csv', index=True)
