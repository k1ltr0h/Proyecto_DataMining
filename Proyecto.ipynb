# %%
import warnings
warnings.filterwarnings('ignore') ## Desactivar Warnings
import pandas as pd
from sklearn.preprocessing import StandardScaler

data = pd.read_csv('Final_Dataset.csv', sep=',', index_col=0)
data["CH4 in Land use change and forestry (tonnes CO₂e)"] = data["CH4 in Land use change and forestry (tonnes CO₂e)"].mul(-1)
display(data)
display(data.describe())
print(data.info())
# Out:
#       Tierras de cultivo[Kha]  Tierras agrícolas[Kha]  Tierras arables[Kha]  \
# Year
# 1998             1.598180e+06            5.281621e+06          1.459381e+06
# 1999             1.601388e+06            5.284178e+06          1.459728e+06
# 2000             1.598015e+06            5.288636e+06          1.454432e+06
# 2001             1.592676e+06            5.281914e+06          1.446734e+06
# 2002             1.587330e+06            5.266591e+06          1.439858e+06
# 2003             1.588052e+06            5.246291e+06          1.437800e+06
# 2004             1.595130e+06            5.210371e+06          1.441324e+06
# 2005             1.600839e+06            5.220849e+06          1.444260e+06
# 2006             1.591868e+06            5.214316e+06          1.432412e+06
# 2007             1.594217e+06            5.209112e+06          1.430834e+06
# 2008             1.595744e+06            5.199566e+06          1.430409e+06
# ...

# %%
cols = data.columns
data = StandardScaler().fit_transform(data)
data = pd.DataFrame(data, columns=cols)
display(data)
# Out:
#     Tierras de cultivo[Kha]  Tierras agrícolas[Kha]  Tierras arables[Kha]  \
# 0                 -0.287811                1.475724              1.805732
# 1                 -0.019513                1.552654              1.841761
# 2                 -0.301582                1.686761              1.292468
# 3                 -0.748014                1.484552              0.494197
# 4                 -1.195112                1.023565             -0.218950
# 5                 -1.134713                0.412861             -0.432416
# 6                 -0.542807               -0.667740             -0.066925
# 7                 -0.065468               -0.352538              0.237591
# 8                 -0.815592               -0.549063             -0.991211
# 9                 -0.619149               -0.705623             -1.154825
# 10                -0.491515               -0.992805             -1.198958
# 11                -0.344065               -1.197718             -1.303902
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

figure, heat = plt.subplots(figsize =(50,50))
data_corr = data.corr()#[["Codigo region", "Codigo comuna", "Poblacion", "Tasa", "Promedio"]]
labels = data_corr.index.values
heat = sns.heatmap(data_corr,
            xticklabels=labels, yticklabels=labels, annot=True)

# %%
display(data.describe())
print(data.info())
# Out:
#        Tierras de cultivo[Kha]  Tierras agrícolas[Kha]  Tierras arables[Kha]  \
# count             1.700000e+01            1.700000e+01          1.700000e+01
# mean             -2.298815e-15           -1.152673e-14          1.277410e-14
# std               1.030776e+00            1.030776e+00          1.030776e+00
# min              -1.195112e+00           -1.197718e+00         -1.315834e+00
# 25%              -6.191485e-01           -7.056231e-01         -9.912109e-01
# 50%              -3.015817e-01           -3.688027e-01         -6.692482e-02
# 75%              -1.951281e-02            1.023565e+00          5.115257e-01
# max               2.057464e+00            1.686761e+00          1.841761e+00
#
#        Tierr. dedicadas a praderas y pastizales perman.[Kha]  \
# count                                       1.700000e+01
# mean                                        4.218847e-15
# std                                         1.030776e+00
# ...

# %%
labels = [""]
sns.pairplot(data, y_vars=cols,x_vars=cols, hue="CO2 Total (tonnes)", height=6)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-bfaeb8d0f0b9> in <module>
# ----> 1 sns.pairplot(data, y_vars=cols,x_vars=cols, hue="CO2 Total (tonnes)", height=6)
#
# ~\Anaconda3\lib\site-packages\seaborn\axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2129     if kind == "scatter":
#    2130         from .relational import scatterplot  # Avoid circular import
# -> 2131         plotter(scatterplot, **plot_kws)
#    2132     elif kind == "reg":
#    2133         from .regression import regplot  # Avoid circular import
#
# ~\Anaconda3\lib\site-packages\seaborn\axisgrid.py in map_offdiag(self, func, **kwargs)
#    1410         self.map_lower(func, **kwargs)
#    1411         if not self._corner:
# ...
